# %%
import pandas as pd
import glob

# %%
df_1 = pd.read_csv("Australia_Wine_Stats.csv")
df_2 = pd.read_csv("Chile_Wine_Stats.csv")
df_3 = pd.read_csv("France_Wine_Stats.csv")
df_4 = pd.read_csv("Italy_Wine_Stats.csv")
df_5 = pd.read_csv("New Zealand_Wine_Stats.csv")
df_6 = pd.read_csv("Portugal_Wine_Stats.csv")
df_7 = pd.read_csv("Spain_Wine_Stats.csv")
df_8 = pd.read_csv("USA_Wine_Stats.csv")

# %%
df = ['Australia_Wine_Stats.csv','Chile_Wine_Stats.csv','France_Wine_Stats.csv','Italy_Wine_Stats.csv','New Zealand_Wine_Stats.csv','Portugal_Wine_Stats.csv','Spain_Wine_Stats.csv','USA_Wine_Stats.csv']
df
# Out:
# ['Australia_Wine_Stats.csv',
#  'Chile_Wine_Stats.csv',
#  'France_Wine_Stats.csv',
#  'Italy_Wine_Stats.csv',
#  'New Zealand_Wine_Stats.csv',
#  'Portugal_Wine_Stats.csv',
#  'Spain_Wine_Stats.csv',
#  'USA_Wine_Stats.csv']

# %%
wine_df = pd.concat((pd.read_csv(i) for i in df)).reset_index(drop=True)
wine_df
# Out:
#       Unnamed: 0                                               Name  Rating  \
# 0              0                          Fields Of Joy Shiraz 2014     4.0
# 1              1                                  Shotfire GSM 2018     3.9
# 2              2                          Passion has Red Lips 2020     3.8
# 3              3           The Hermit Crab Viognier - Marsanne 2018     3.8
# 4              4          Cabernet Sauvignon (Batch No. 1 & 3) 2019     3.8
# ...          ...                                                ...     ...
# 5140         667  Katherine Goldschmidt Stonemason Hill Cabernet...     4.1
# 5141         668                           Pessimist Red Blend 2020     4.0
# 5142         669                            Cabernet Sauvignon 2013     3.8
# 5143         670                                  Petit Verdot 2017     4.2
# 5144         671                          Freakshow Chardonnay 2020     3.8
#
#       Number of Ratings  Price  \
# ...

# %%
wine_df = wine_df.drop_duplicates()
wine_df
# Out:
#       Unnamed: 0                                               Name  Rating  \
# 0              0                          Fields Of Joy Shiraz 2014     4.0
# 1              1                                  Shotfire GSM 2018     3.9
# 2              2                          Passion has Red Lips 2020     3.8
# 3              3           The Hermit Crab Viognier - Marsanne 2018     3.8
# 4              4          Cabernet Sauvignon (Batch No. 1 & 3) 2019     3.8
# ...          ...                                                ...     ...
# 5140         667  Katherine Goldschmidt Stonemason Hill Cabernet...     4.1
# 5141         668                           Pessimist Red Blend 2020     4.0
# 5142         669                            Cabernet Sauvignon 2013     3.8
# 5143         670                                  Petit Verdot 2017     4.2
# 5144         671                          Freakshow Chardonnay 2020     3.8
#
#       Number of Ratings  Price  \
# ...

# %%
wine_df = wine_df.dropna()
wine_df
# Out:
#       Unnamed: 0                          Name  Rating  Number of Ratings  \
# 1              1             Shotfire GSM 2018     3.9                 36
# 5              5     Passion has Red Lips 2014     3.8                648
# 7              7            Jester Shiraz 2018     3.9                658
# 8              8        Shotfire Quartage 2016     3.8                 93
# 9              9        Stonehorse Shiraz 2018     4.0                288
# ...          ...                           ...     ...                ...
# 5138         665  Sonoma Coast Pinot Noir 2013     4.1                193
# 5139         666             Dry Riesling 2015     3.9                184
# 5141         668      Pessimist Red Blend 2020     4.0                574
# 5142         669       Cabernet Sauvignon 2013     3.8               4612
# 5144         671     Freakshow Chardonnay 2020     3.8                160
#
#       Price                                             Region  \
# ...

# %%
wine_df.head()
# Out:
#    Unnamed: 0                       Name  Rating  Number of Ratings  Price  \
# 1           1          Shotfire GSM 2018     3.9                 36  19.49
# 5           5  Passion has Red Lips 2014     3.8                648  18.49
# 7           7         Jester Shiraz 2018     3.9                658  22.00
# 8           8     Shotfire Quartage 2016     3.8                 93  17.99
# 9           9     Stonehorse Shiraz 2018     4.0                288  29.17
#
#                                               Region            Winery  \
# 1              Australia / South Australia / Barossa      Thorn-Clarke
# 5  Australia / South Australia / Fleurieu / McLar...  Some Young Punks
# 7  Australia / South Australia / Fleurieu / McLar...            Mitolo
# 8              Australia / South Australia / Barossa      Thorn-Clarke
# 9  Australia / South Australia / Barossa / Baross...           Kaesler
#
#                      Wine style  Alcohol content  \
# ...

# %%
import matplotlib.pyplot as plt
plt.boxplot(wine_df['Rating'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(wine_df['Price'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(wine_df['Number of Ratings'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(wine_df['Alcohol content'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(wine_df['Bold'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(wine_df['Tannin'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(wine_df['Sweet'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot(wine_df['Acidic'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
wine_df['Country'] = wine_df['Region']
wine_df['Country'] = wine_df['Region'].str.split('/').str[0].str.strip()
wine_df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_21344\1856639378.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine_df['Country'] = wine_df['Region']
# C:\Users\Dell\AppData\Local\Temp\ipykernel_21344\1856639378.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine_df['Country'] = wine_df['Region'].str.split('/').str[0].str.strip()
#       Unnamed: 0                          Name  Rating  Number of Ratings  \
# 1              1             Shotfire GSM 2018     3.9                 36
# ...

# %%
wine_df['Country_Region'] = wine_df['Region']
wine_df['Country_Region'] = wine_df['Region'].str.split('/').str[-1].str.strip()
wine_df
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_21344\3267681877.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine_df['Country_Region'] = wine_df['Region']
# C:\Users\Dell\AppData\Local\Temp\ipykernel_21344\3267681877.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wine_df['Country_Region'] = wine_df['Region'].str.split('/').str[-1].str.strip()
#       Unnamed: 0                          Name  Rating  Number of Ratings  \
# ...

# %%
food_pairings = set([item for sublist in wine_df['Food pairings'] for item in sublist])
food = {'Pasta', 'Beef', 'Lamb', 'Poultry', 'Cheese', 'Chicken', 'Vegetables'}
for food in food_pairings:
    df[food] = df['Food pairings'].apply(lambda x: food in x)

wine_df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 4
#       2 food = {'Pasta', 'Beef', 'Lamb', 'Poultry', 'Cheese', 'Chicken', 'Vegetables'}
#       3 for food in food_pairings:
# ----> 4     df[food] = df['Food pairings'].apply(lambda x: food in x)
#       6 wine_df
#
# TypeError: list indices must be integers or slices, not str

# %%
wine_df.drop(columns=['Bold','Tannin','Acidic','Sweet'])
# Out:
#       Unnamed: 0                          Name  Rating  Number of Ratings  \
# 1              1             Shotfire GSM 2018     3.9                 36
# 5              5     Passion has Red Lips 2014     3.8                648
# 7              7            Jester Shiraz 2018     3.9                658
# 8              8        Shotfire Quartage 2016     3.8                 93
# 9              9        Stonehorse Shiraz 2018     4.0                288
# ...          ...                           ...     ...                ...
# 5138         665  Sonoma Coast Pinot Noir 2013     4.1                193
# 5139         666             Dry Riesling 2015     3.9                184
# 5141         668      Pessimist Red Blend 2020     4.0                574
# 5142         669       Cabernet Sauvignon 2013     3.8               4612
# 5144         671     Freakshow Chardonnay 2020     3.8                160
#
#       Price                                             Region  \
# ...
